# %%
import json
import os

# %%
input_dir = "/home/hannw/repos/kaggle-environments/experiments/repeated_8player"
games = []

for i in range(8):
    fpath = os.path.join(input_dir, f"game_replay_{i}.json")
    games.append(json.load(open(fpath)))

# %%
for i in range(8):
    print(games[0]['info']['GAME_END']['winner_team'])
# Out:
# Werewolves
# Werewolves
# Werewolves
# Werewolves
# Werewolves
# Werewolves
# Werewolves
# Werewolves

# %%
games[0]['info']['GAME_END']
# Out:
# {'all_players': [{'agent': {'agent_harness_name': 'llm_harness',
#     'agent_id': 'llm_harness/xai/grok-4-latest',
#     'display_name': 'xai/grok-4-latest',
#     'id': 'grok-4',
#     'llms': [{'model_name': 'xai/grok-4-latest', 'properties': {}}],
#     'role': 'Werewolf',
#     'thumbnail': 'https://images.seeklogo.com/logo-png/61/1/grok-logo-png_seeklogo-613403.png'},
#    'alive': True,
#    'eliminated_during_day': -1,
#    'eliminated_during_phase': None,
#    'id': 'grok-4',
#    'role': {'descriptions': 'A member of the Werewolf team. At night, works with other werewolves to vote on eliminating one player.',
#     'name': 'Werewolf',
#     'night_priority': 2,
#     'team': 'Werewolves'}},
#   {'agent': {'agent_harness_name': 'llm_harness',
#     'agent_id': 'llm_harness/together_ai/Qwen/Qwen3-235B-A22B-Instruct-2507-tput',
#     'display_name': 'together_ai/Qwen/Qwen3-235B-A22B-Instruct-2507-tput',
#     'id': 'qwen3',
# ...
